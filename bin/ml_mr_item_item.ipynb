# %% [markdown]
# ### Carga de las librerías

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Carga de los datos

# %%
df_BD = pd.DataFrame(pd.read_csv(r"../data/osg_api.csv"))

# %%
df_DB_MR = pd.DataFrame(pd.read_csv(r"../data/osg_mr.csv"))
df_DB_MR.sample(5)
# Out:
#                                                   genres  \
# 3078   action,adventure,casual,free to play,massively...
# 16432                                   adventure,casual
# 17691                                 indie,rpg,strategy
# 9293                                           adventure
# 8753                               casual,indie,strategy
#
#                                                    title  \
# 3078                           Time Tracer's DLC Package
# 16432                             Kult of Ktulu: Olympic
# 17691  Fantasy Grounds - Rippers Companion (Savage Wo...
# 9293                    LEGO® Worlds: Classic Space Pack
# 8753                                          CrossCells
#
#                                                     tags  \
# 3078   free to play,adventure,rpg,massively multiplay...
# 16432                      casual,adventure,lovecraftian
# 17691                                 strategy,rpg,indie
# 9293                                adventure,space,lego
# 8753                        casual,indie,strategy,puzzle
#
#                                                    specs price  early_access  \
# 3078   single-player,multi-player,mmo,co-op,downloada...  9.99         False
# 16432  single-player,steam achievements,steam trading...  5.99         False
# 17691  multi-player,co-op,cross-platform multiplayer,...  9.99         False
# 9293   single-player,online multi-player,online co-op...  3.99         False
# 8753        single-player,steam achievements,steam cloud  2.99         False
#
#        item_id                   developer  anio_lanzamiento
# 3078    357660                         KOG              2015
# 16432   586230              Grand Cauldron              2017
# 17691   545310         SmiteWorks USA, LLC              2016
# 9293    641000  TT Games,Traveller's Tales              2017
# 8753    632000               Matthew Brown              2017

# %%
caracteristicas = ["item_id", "genres", "title", "tags", "specs", "price", "early_access", "developer", "anio_lanzamiento"]
filtro = df_DB_MR[caracteristicas]

# %%
filtro[caracteristicas] = filtro[caracteristicas].astype(str)

# %%
for caracteristica in caracteristicas:
    filtro[caracteristica] = filtro[caracteristica].apply(lambda x: x.lower().replace(" ",""))

# %%
filtro.sample(10)
# Out:
#       item_id                         genres  \
# 24631  303510  action,adventure,casual,indie
# 23313  356010                      indie,rpg
# 19463  480722            freetoplay,strategy
# 7240   436530                   action,indie
# 14831  576740            action,indie,sports
# 23497  342270                 indie,strategy
# 25853  215919                       strategy
# 143     21600                casual,strategy
# 1106    70616                       strategy
# 24518  292712               action,adventure
#
#                                         title  \
# 24631               dungeons:theeyeofdraconus
# 23313              theheroofkendrickstonedemo
# 19463        totalwarbattles:kingdom-1700gold
# 7240                                 bullshot
# 14831                               footrock2
# 23497                 theartoftherecameanecho
# 25853         magic2014“bounceandboon”deckkey
# 143                               ageofbooty™
# 1106   wormsultimatemayhem-multiplayerpackdlc
# 24518           lego®thehobbit™-thebattlepack
#
#                                                     tags  \
# 24631  indie,action,adventure,beatemup,casual,co-op,o...
# 23313                                          rpg,indie
# 19463                                strategy,freetoplay
# 7240   indie,action,retro,platformer,arcade,space,sin...
# 14831                                action,indie,sports
# 23497                                     strategy,indie
# 25853                                           strategy
# 143                              strategy,casual,pirates
# 1106                                            strategy
# 24518                              action,adventure,lego
#
#                                                    specs  price early_access  \
# 24631  single-player,multi-player,co-op,shared/splits...   3.99        false
# 23313  single-player,gamedemo,steamachievements,capti...    nan        false
# 19463     single-player,multi-player,downloadablecontent  14.99        false
# 7240   single-player,multi-player,onlinemulti-player,...   4.99        false
# 14831             single-player,partialcontrollersupport   0.99        false
# 23497  single-player,downloadablecontent,steamachieve...   4.99        false
# 25853  single-player,multi-player,co-op,shared/splits...   0.99        false
# 143                                        single-player    nan        false
# 1106   single-player,multi-player,shared/splitscreen,...   2.99        false
# 24518  single-player,shared/splitscreen,downloadablec...   1.99        false
#
#                                     developer anio_lanzamiento
# 24631                         suckerfreegames             2014
# 23313                           choiceofgames             2015
# 19463                        creativeassembly             2016
# 7240                          gatosalvajes.l.             2016
# 14831                              nobodyshot             2017
# 23497                          iridiumstudios             2015
# 25853                          stainlessgames             2013
# 143                          certainaffinity™             2009
# 1106                         team17digitalltd             2013
# 24518  traveller'stales,feralinteractive(mac)             2014

# %%
def crear_sopa(dato):
    return  dato["item_id"] + " " +dato["genres"] + " " + dato["title"] + " " + dato["tags"] + " " + dato["specs"]  + " " + dato["price"] + " " + dato["early_access"] + " " + dato["developer"] + " " + dato["anio_lanzamiento"]

# %%
filtro["caracteristicas"] = filtro.apply(crear_sopa, axis=1)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

modelo = TfidfVectorizer(stop_words="english")
matriz_del_modelo = modelo.fit_transform(filtro["caracteristicas"])

# %%
from sklearn.metrics.pairwise import cosine_similarity

similitud_del_coseno = cosine_similarity(X=matriz_del_modelo, Y=matriz_del_modelo)

# %%
similitud_del_coseno.shape
# Out:
# (27883, 27883)

# %%
similitud_del_coseno2 = pd.DataFrame(similitud_del_coseno)

# %%
similitud_del_coseno2 = similitud_del_coseno2.iloc[:, :5]

# %%
similitud_del_coseno2.shape
# Out:
# (27883, 5)

# %%
#np.savetxt("../data/osg_mr_sim_cos.txt", similitud_del_coseno)

# %%
filtro = filtro.reset_index()
indice = pd.Series(filtro.index, index=filtro["item_id"])

# %%
filtro
# Out:
#        index item_id                                     genres  \
# 0          0  670290  casual,freetoplay,indie,simulation,sports
# 1          1  767400                    action,adventure,casual
# 2          2  775880                   racing,simulation,sports
# 3          3  775881                   racing,simulation,sports
# 4          4  752360                           action,indie,rpg
# ...      ...     ...                                        ...
# 27878  27878  766460                                 simulation
# 27879  27879  759900                       action,adventure,rpg
# 27880  27880  250440                               action,indie
# 27881  27881  755310                  utilities,videoproduction
# 27882  27882  658870                               casual,indie
#
#                               title  \
# 0               realpool3d-poolians
# 1                           弹炸人2222
# 2           rcplane3-canyonscenario
# 3                    rcplane3-f-53b
# 4                        fallenmage
# ...                             ...
# 27878              triremecommander
# 27879  the13thheir-ragnarokchapter2
# 27880                    tetrapulse
# 27881        cyberlinkyoucam7deluxe
# 27882              exit2-directions
#
#                                                     tags  \
# 0      freetoplay,simulation,sports,casual,indie,mult...
# 1                                action,adventure,casual
# 2                               simulation,racing,sports
# 3                               simulation,racing,sports
# 4                                       action,rpg,indie
# ...                                                  ...
# 27878                                         simulation
# 27879                      action,adventure,rpg,rpgmaker
# 27880                                 indie,action,co-op
# 27881                          utilities,videoproduction
# 27882  indie,casual,puzzle,singleplayer,atmospheric,r...
#
#                                                    specs       price  \
# 0      single-player,multi-player,onlinemulti-player,...  freetoplay
# 1                                          single-player        0.99
# 2      single-player,downloadablecontent,steamachieve...        2.99
# 3      single-player,cross-platformmultiplayer,downlo...        2.99
# 4                                          single-player        1.99
# ...                                                  ...         ...
# 27878                                      single-player       17.99
# 27879                    single-player,steamachievements         nan
# 27880  multi-player,co-op,shared/splitscreen,steamach...         nan
# 27881                                                nan       29.99
# 27882         single-player,steamachievements,steamcloud        4.99
#
#       early_access            developer anio_lanzamiento  \
# 0            false         poolians.com             2017
# 1            false                 彼岸领域             2017
# 2            false         frozenpepper             2017
# 3            false         frozenpepper             2017
# 4            false             dev4play             2016
# ...            ...                  ...              ...
# 27878        false          peterturcan             2017
# 27879        false  samueljamesswartout             2017
# 27880        false           theamiable             2016
# 27881        false            cyberlink             2017
# 27882        false        xropi,stev3ns             2017
#
#                                          caracteristicas
# 0      670290 casual,freetoplay,indie,simulation,spor...
# 1      767400 action,adventure,casual 弹炸人2222 action,...
# 2      775880 racing,simulation,sports rcplane3-canyo...
# 3      775881 racing,simulation,sports rcplane3-f-53b...
# 4      752360 action,indie,rpg fallenmage action,rpg,...
# ...                                                  ...
# 27878  766460 simulation triremecommander simulation ...
# 27879  759900 action,adventure,rpg the13thheir-ragnar...
# 27880  250440 action,indie tetrapulse indie,action,co...
# 27881  755310 utilities,videoproduction cyberlinkyouc...
# 27882  658870 casual,indie exit2-directions indie,cas...
#
# [27883 rows x 11 columns]

# %%
def obtener_recomendaciones(item_id):
    
    idx = indice[item_id]
    print(idx)

    puntajes_similares = list(enumerate(similitud_del_coseno[idx]))

    puntajes_similares = sorted(puntajes_similares, key = lambda x: x[1], reverse=True)

    puntajes_similares = puntajes_similares[1:6]
    
    juegos_indices = [int(i[0]) for i in puntajes_similares]

    return {f"Recomendación de 5 juegos relacionados con ({item_id}) "+df_BD["title"][item_id]:[{f"Recomendación {i+1}":{"Identificador":df_BD["item_id"].iloc[juegos_indices[i]], "Título":df_BD["title"].iloc[juegos_indices[i]]}} for i in range(len(juegos_indices))]}

# %%
item_id = 7740
obtener_recomendaciones(item_id)
# Out:
# 7740
# {'Recomendación de 5 juegos relacionados con (7740) Off-Road Paradise: Trial 4x4': [{'Recomendación 1': {'Identificador': 414260,
#     'Título': 'Ironclads 2: American Civil War'}},
#   {'Recomendación 2': {'Identificador': 399430, 'Título': 'Tinboy'}},
#   {'Recomendación 3': {'Identificador': 428140,
#     'Título': 'TowerClimb - Extended Original Soundtrack'}},
#   {'Recomendación 4': {'Identificador': 526640,
#     'Título': 'WRC 6 YARIS WRC Test car'}},
#   {'Recomendación 5': {'Identificador': 283490,
#     'Título': 'IHF Handball Challenge 12'}}]}

# %%
np.savetxt(f"../data/osg_mr_sim_cos.txt",similitud_del_coseno)

# %%
indice.index =indice.index.astype(int)

# %%
indice.to_csv(f"../data/osg_mr_indice.csv", index=True)
